# %%
import gym
from stable_baselines3 import PPO
import os
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %%
env = gym.make('LunarLander-v2')
env_id = "LunarLander-v2"

models_dir = "models/PPO"
n_envs= 5
eval_envs = make_vec_env(env_id, n_envs=5)
eval_freq = int(1e5)
eval_freq = max(eval_freq // n_envs, 1)

# env = make_vec_env('LunarLander-v2', n_envs=32)
env = gym.make('LunarLander-v2')
model = PPO(
        policy = 'MlpPolicy',
        env = env,
        n_steps = 5000,
        batch_size = 4096,
        learning_rate=0.003,
        clip_range=0.3,
        n_epochs = 30,
        gamma = 0.999,
        vf_coef=0.5,
        gae_lambda = 0.98,
        ent_coef = 0.01,
        verbose=1)

def train_model(timesteps=1000, iter=10, saved_model_fn_int=0):
    #saved_model_fn_int: this parameter is for using past model.
    TIMESTEPS = timesteps
    for i in range(iter):
        model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="PPO")
        saved_model_file_name = saved_model_fn_int + str(i * TIMESTEPS)
        model.save(f"{models_dir}/{saved_model_file_name}")


train_model(timesteps=1000, iter=30, saved_model_fn_int='PPO')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.3     |
# |    ep_rew_mean     | -188     |
# | time/              |          |
# |    fps             | 4993     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5000     |
# ---------------------------------
# /Users/utkusaglam/Desktop/huggingface_2/deep-rl-learning/deep-rl-learning/stable-baselines3/venv/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:276: UserWarning: Path 'models/PPO' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.6     |
# |    ep_rew_mean     | -174     |
# | time/              |          |
# |    fps             | 4809     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.9     |
# |    ep_rew_mean     | -150     |
# | time/              |          |
# |    fps             | 5085     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 15000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.2     |
# |    ep_rew_mean     | -140     |
# | time/              |          |
# |    fps             | 5038     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 20000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.7     |
# |    ep_rew_mean     | -145     |
# | time/              |          |
# |    fps             | 4859     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 25000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -135     |
# | time/              |          |
# |    fps             | 3276     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 30000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 116      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    fps             | 3256     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 35000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 112      |
# |    ep_rew_mean     | -79.6    |
# | time/              |          |
# |    fps             | 4793     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 40000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | -53      |
# | time/              |          |
# |    fps             | 4705     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 45000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | -48      |
# | time/              |          |
# |    fps             | 2811     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 50000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | -40.2    |
# | time/              |          |
# |    fps             | 2663     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 55000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 175      |
# |    ep_rew_mean     | -32.4    |
# | time/              |          |
# |    fps             | 1751     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 60000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | -24.6    |
# | time/              |          |
# |    fps             | 1406     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 65000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 244      |
# |    ep_rew_mean     | -18.5    |
# | time/              |          |
# |    fps             | 1628     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 70000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 289      |
# |    ep_rew_mean     | -10.5    |
# | time/              |          |
# |    fps             | 1219     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 75000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 326      |
# |    ep_rew_mean     | 0.403    |
# | time/              |          |
# |    fps             | 1336     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 80000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 369      |
# |    ep_rew_mean     | 5.78     |
# | time/              |          |
# |    fps             | 1052     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 85000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 412      |
# |    ep_rew_mean     | 16.3     |
# | time/              |          |
# |    fps             | 1238     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 90000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 443      |
# |    ep_rew_mean     | 19       |
# | time/              |          |
# |    fps             | 1726     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 95000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 472      |
# |    ep_rew_mean     | 18       |
# | time/              |          |
# |    fps             | 1732     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 100000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 511      |
# |    ep_rew_mean     | 18.6     |
# | time/              |          |
# |    fps             | 1575     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 105000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 530      |
# |    ep_rew_mean     | 20.2     |
# | time/              |          |
# |    fps             | 1390     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 110000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 564      |
# |    ep_rew_mean     | 24.3     |
# | time/              |          |
# |    fps             | 1798     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 115000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 591      |
# |    ep_rew_mean     | 25.4     |
# | time/              |          |
# |    fps             | 1596     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 120000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 613      |
# |    ep_rew_mean     | 30.5     |
# | time/              |          |
# |    fps             | 1528     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 125000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 621      |
# |    ep_rew_mean     | 32.9     |
# | time/              |          |
# |    fps             | 1723     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 130000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 645      |
# |    ep_rew_mean     | 42.7     |
# | time/              |          |
# |    fps             | 1514     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 135000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 637      |
# |    ep_rew_mean     | 42.8     |
# | time/              |          |
# |    fps             | 1254     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 140000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 625      |
# |    ep_rew_mean     | 43.1     |
# | time/              |          |
# |    fps             | 1458     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 145000   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 616      |
# |    ep_rew_mean     | 44.1     |
# | time/              |          |
# |    fps             | 1752     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 150000   |
# ---------------------------------

# %% [markdown]
# EVALUATE MODEL

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
models_dir = "models/PPO/PPO29000"

env = gym.make('LunarLander-v2')  # continuous: LunarLanderContinuous-v2
env.reset()
env_id = "LunarLander-v2"

model_path = f"{models_dir}.zip"
model = PPO.load(model_path, env=env)
eval_env = make_vec_env(env_id,seed=0,vec_env_cls=DummyVecEnv)
# eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(type(mean_reward))
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <class 'numpy.float64'>
# mean_reward=84.12 +/- 150.96292115774034
